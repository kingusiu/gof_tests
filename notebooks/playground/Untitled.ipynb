# %%
import numpy as np
import ROOT as rt
import root_numpy as rtnp
import matplotlib.pyplot as plt

# %%
xx = np.random.exponential(size=1000)
_ = plt.hist(xx,bins=100)

# %%
hh = rt.TH1D( 'h1', 'Test random', 100, 0, max(xx))
rtnp.fill_hist(hh, xx)

# %%
c = rt.TCanvas()
c.Draw()
hh.Draw()

# %%
# change linecolor
hh.SetLineColor(2)

# %%
c = rt.TCanvas()
c.Draw()
hh.Draw()

# %%
# change to markers
hh.SetMarkerStyle(8)
hh.SetMarkerColor(2)
hh.SetMarkerSize(0.75)

# %%
c = rt.TCanvas()
c.Draw()
hh.Draw('e')
